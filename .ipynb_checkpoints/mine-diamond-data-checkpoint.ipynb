# %% [markdown]
# # Mine Diamond Data
#
# ## Introduction
# In this notebook we will mine our data from as many sources as possible to prepare our dataset. We will target diamond merchants on the web, starting with Brilliant Earth (sorry Brilliant Earth... But thanks for the data).
#
# We'll start by importing our packages for scraping and regular expression, then quickly making a function to get the page content of a link.

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
def get_page_content(page_link):
    page_response = requests.get(page_link, timeout=5)
    page_content = BeautifulSoup(page_response.content)
    return(page_content)

# %%
def cleanhtml(raw_html):
    """
    Remove HTML tags from string.
    """
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', raw_html)
    return(cleantext)

# %% [markdown]
# ## Blue Nile

# %%
# For conciseness, Blue Nile we will denote as 'bn'
bn_link = 'https://www.bluenile.com/uk/diamond-search'

# %%
def get_bn_headers(page_content):
    """
    Retrieves the headers for our Blue Nile dataframe
    """
    headers_grid = page_content.find('div',{'class':'grid-header normal-header'})
    headers_row = headers_grid.find('div', {'class':'row'})
    
    # Find all headers, and remove the tags from the string
    headers_containers = []
    for div in headers_row.find_all('div'):
        headers_containers.append(cleanhtml(str(div.find('span'))))
    
    # Remove all 'None' string values from list
    headers = list(filter(('None').__ne__, headers_containers))
    return(headers)

# %%
bn_page_content = get_page_content(bn_link)
bn_headers = get_bn_headers(bn_page_content)
print(bn_headers)
# Out:
# ['Compare', 'Shape', 'Price', 'Carat', 'Cut', 'Colour', 'Clarity', 'Polish', 'Symmetry', 'Fluorescence', 'Depth', 'Table', 'L/W', 'Price/Ct', 'Culet', 'Stock No.', 'Dispatch Date']

# %%
def find_bn_default_filters(page_content):
    page_content.find('div',{'class':'filter-container image-type-filter toggled'}).find('input')             # Image view
    page_content.find('div',{'class':'astor-filter-layout inline-filter'}).find('input')                      # ASTOR checkbox
    
    page_content.find('div',{'class':'filter-container price-filter toggled'}).find_all('input')              # Price
    page_content.find('div',{'class':'filter-container carat-filter toggled with-tooltip'}).find_all('input') # Carat
    page_content.find('div',{'class':'astor-filter-layout inline-filter'}).find('input')                      
    page_content.find('div',{'class':'astor-filter-layout inline-filter'}).find('input') 
    page_content.find('div',{'class':'astor-filter-layout inline-filter'}).find('input')

# %%
bn_page_content.find('div',{'class':'astor-filter-layout inline-filter'}).find('input')
# Out:
# <input type="checkbox"/>

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
browser = webdriver.Chrome('C:/Users/Edward Sims/Downloads/chromedriver.exe')

# %%
browser.get('https://www.brilliantearth.com/loose-diamonds/search/')

# %%
oval_details = browser.find_element_by_class_name('oval-details')
cushion_details = browser.find_element_by_class_name('cushion-details')
princess_details = browser.find_element_by_class_name('princess-details')
pear_details = browser.find_element_by_class_name('pear-details')
emerald_details = browser.find_element_by_class_name('emerald-details')
marquise_details = browser.find_element_by_class_name('marquise-details')
asscher_details = browser.find_element_by_class_name('asscher-details')
radiant_details = browser.find_element_by_class_name('radiant-details')
heart_details = browser.find_element_by_class_name('heart-details')

# %%
oval_details.click()
cushion_details.click()
princess_details.click()
pear_details.click()
emerald_details.click()
marquise_details.click()
asscher_details.click()
radiant_details.click()
heart_details.click()

# %%
browser.find_element_by_id('min_price_display').clear()
browser.find_element_by_id('max_price_display').clear()

# %%
min_price = browser.find_element_by_id('min_price_display')

# %%
min_price.send_keys('420')

# %%
min_price.send_keys(Keys.RETURN)
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-197-99c7ba8a2531> in <module>
# ----> 1 min_price.send_keys(Keys.RETURN)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in send_keys(self, *value)
#     477         self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     478                       {'text': "".join(keys_to_typing(value)),
# --> 479                        'value': keys_to_typing(value)})
#     480
#     481     # RenderedWebElement Items
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=74.0.3729.169)
#   (Driver info: chromedriver=74.0.3729.6 (255758eccf3d244491b8a1317aa76e1ce10d57e9-refs/branch-heads/3729@{#29}),platform=Windows NT 10.0.18362 x86_64)

# %%
max_price = browser.find_element_by_id('max_price_display')

# %%
max_price.send_keys('5000')

# %%
page_table = bn_page_content.find('div',{'class':'grid-body'})

# %%
for a in page_table.find_all('a'):
    for div in a.find_all('div',{'class':'shape-cell-wrapper'}):
        print(div)
# Out:
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>
# <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>

# %%
shapes = []
for a in page_table.find_all('a'):
    for div in a.find_all('div',{'class':'shape-cell-wrapper'}):
        shapes.append(cleanhtml(str(div)))
    for div in a.find_all('div',{'class':'shape-cell-wrapper'}):
        shapes.append(cleanhtml(str(div)))
    for div in a.find_all('div',{'class':'shape-cell-wrapper'}):
        shapes.append(cleanhtml(str(div)))
    for div in a.find_all('div',{'class':'shape-cell-wrapper'}):
        shapes.append(cleanhtml(str(div)))
    for div in a.find_all('div',{'class':'shape-cell-wrapper'}):
        shapes.append(cleanhtml(str(div)))
    for div in a.find_all('div',{'class':'shape-cell-wrapper'}):
        shapes.append(cleanhtml(str(div)))
    for div in a.find_all('div',{'class':'shape-cell-wrapper'}):
        shapes.append(cleanhtml(str(div)))
    for div in a.find_all('div',{'class':'shape-cell-wrapper'}):
        shapes.append(cleanhtml(str(div)))
    for div in a.find_all('div',{'class':'shape-cell-wrapper'}):
        shapes.append(cleanhtml(str(div)))
    
print(rows_containers)
# Out:
# ['Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round', 'Round']

# %%
rows_containers
# Out:
# [<div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£277.20</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div>,
#  <div class="row-cell color"><span class="">I</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">64.5</span></div>,
#  <div class="row-cell table"><span class="">56.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,205</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12116667</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£278.40</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">F</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">62.1</span></div>,
#  <div class="row-cell table"><span class="">59.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.00</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,210</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD11975573</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£279.60</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div>,
#  <div class="row-cell color"><span class="">G</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">58.9</span></div>,
#  <div class="row-cell table"><span class="">59.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,216</span></div>,
#  <div class="row-cell culet"><span class="">Very Small</span></div>,
#  <div class="row-cell skus"><span class="">LD11945759</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£279.60</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div>,
#  <div class="row-cell color"><span class="">F</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Excellent</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">60.1</span></div>,
#  <div class="row-cell table"><span class="">62.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,216</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12116464</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£279.60</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div>,
#  <div class="row-cell color"><span class="">F</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">64.8</span></div>,
#  <div class="row-cell table"><span class="">56.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,216</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12121615</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£280.80</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div>,
#  <div class="row-cell color"><span class="">H</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">64.4</span></div>,
#  <div class="row-cell table"><span class="">58.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,221</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD11590566</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£280.80</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">F</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">63.0</span></div>,
#  <div class="row-cell table"><span class="">57.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,221</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD11975570</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£280.80</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div>,
#  <div class="row-cell color"><span class="">F</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Excellent</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">59.2</span></div>,
#  <div class="row-cell table"><span class="">60.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,221</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD11996373</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£282.00</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">I</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">63.4</span></div>,
#  <div class="row-cell table"><span class="">55.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.00</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,226</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12116581</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£282.00</span></div>,
#  <div class="row-cell carat"><span class="">0.24</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div>,
#  <div class="row-cell color"><span class="">G</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Excellent</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">65.6</span></div>,
#  <div class="row-cell table"><span class="">59.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,175</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12116649</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£282.00</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">I</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">60.6</span></div>,
#  <div class="row-cell table"><span class="">61.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,226</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12116677</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£283.20</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div>,
#  <div class="row-cell color"><span class="">J</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">63.2</span></div>,
#  <div class="row-cell table"><span class="">60.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,231</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD11647661</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£283.20</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">F</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">62.0</span></div>,
#  <div class="row-cell table"><span class="">60.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,231</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD11975534</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£283.20</span></div>,
#  <div class="row-cell carat"><span class="">0.24</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div>,
#  <div class="row-cell color"><span class="">E</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">63.0</span></div>,
#  <div class="row-cell table"><span class="">56.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,180</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12047903</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£284.40</span></div>,
#  <div class="row-cell carat"><span class="">0.24</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div>,
#  <div class="row-cell color"><span class="">E</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">65.1</span></div>,
#  <div class="row-cell table"><span class="">57.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,185</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD10176592</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£284.40</span></div>,
#  <div class="row-cell carat"><span class="">0.24</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">G</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">60.6</span></div>,
#  <div class="row-cell table"><span class="">60.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,185</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12116630</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£284.40</span></div>,
#  <div class="row-cell carat"><span class="">0.25</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">J</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">61.4</span></div>,
#  <div class="row-cell table"><span class="">61.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,138</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12121632</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£285.60</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div>,
#  <div class="row-cell color"><span class="">I</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">61.2</span></div>,
#  <div class="row-cell table"><span class="">59.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,242</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12116597</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£285.60</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">I</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Excellent</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">62.5</span></div>,
#  <div class="row-cell table"><span class="">60.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,242</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12116683</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£286.80</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div>,
#  <div class="row-cell color"><span class="">E</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">59.4</span></div>,
#  <div class="row-cell table"><span class="">61.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,247</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD11967649</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£286.80</span></div>,
#  <div class="row-cell carat"><span class="">0.25</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">G</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">60.8</span></div>,
#  <div class="row-cell table"><span class="">57.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.00</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,147</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12121671</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£286.80</span></div>,
#  <div class="row-cell carat"><span class="">0.24</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div>,
#  <div class="row-cell color"><span class="">I</span></div>,
#  <div class="row-cell clarity"><span class="">VS1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">57.9</span></div>,
#  <div class="row-cell table"><span class="">61.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,195</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12233799</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£288.00</span></div>,
#  <div class="row-cell carat"><span class="">0.24</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">D</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">59.7</span></div>,
#  <div class="row-cell table"><span class="">61.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.00</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,200</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD06933105</span></div>,
#  <div class="row-cell date"><span class="">Jun 5</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£288.00</span></div>,
#  <div class="row-cell carat"><span class="">0.24</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">F</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">63.1</span></div>,
#  <div class="row-cell table"><span class="">57.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.00</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,200</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD10176491</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£289.20</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">I</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">60.5</span></div>,
#  <div class="row-cell table"><span class="">61.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,257</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12116579</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£289.20</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">I</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">63.8</span></div>,
#  <div class="row-cell table"><span class="">55.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.00</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,257</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12116610</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£289.20</span></div>,
#  <div class="row-cell carat"><span class="">0.24</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div>,
#  <div class="row-cell color"><span class="">F</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">58.9</span></div>,
#  <div class="row-cell table"><span class="">62.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,205</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12116614</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£289.20</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">I</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">63.3</span></div>,
#  <div class="row-cell table"><span class="">57.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,257</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12116676</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£289.20</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">I</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">63.6</span></div>,
#  <div class="row-cell table"><span class="">57.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,257</span></div>,
# ...
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£291.60</span></div>,
#  <div class="row-cell carat"><span class="">0.24</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">F</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">63.9</span></div>,
#  <div class="row-cell table"><span class="">57.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,215</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12121662</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£292.80</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div>,
#  <div class="row-cell color"><span class="">D</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">Faint</span></div>,
#  <div class="row-cell depth"><span class="">63.4</span></div>,
#  <div class="row-cell table"><span class="">57.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.00</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,273</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD06933658</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£292.80</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">E</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">63.8</span></div>,
#  <div class="row-cell table"><span class="">56.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.00</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,273</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD11590543</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£292.80</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">E</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Excellent</span></div>,
#  <div class="row-cell symmetry"><span class="">Excellent</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">63.1</span></div>,
#  <div class="row-cell table"><span class="">57.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.00</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,273</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD11590575</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£292.80</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">E</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">59.7</span></div>,
#  <div class="row-cell table"><span class="">62.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,273</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD11812066</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£292.80</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Very Good</span><span class="label-small-view">Very Good</span></div>,
#  <div class="row-cell color"><span class="">E</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">61.9</span></div>,
#  <div class="row-cell table"><span class="">58.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.02</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,273</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD11812069</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£292.80</span></div>,
#  <div class="row-cell carat"><span class="">0.23</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div>,
#  <div class="row-cell color"><span class="">G</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">58.5</span></div>,
#  <div class="row-cell table"><span class="">61.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,273</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD11942267</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£292.80</span></div>,
#  <div class="row-cell carat"><span class="">0.24</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Ideal</span><span class="label-small-view">Ideal</span></div>,
#  <div class="row-cell color"><span class="">F</span></div>,
#  <div class="row-cell clarity"><span class="">SI1</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Excellent</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">59.9</span></div>,
#  <div class="row-cell table"><span class="">59.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,220</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12047902</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£292.80</span></div>,
#  <div class="row-cell carat"><span class="">0.25</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div>,
#  <div class="row-cell color"><span class="">F</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  <div class="row-cell depth"><span class="">64.6</span></div>,
#  <div class="row-cell table"><span class="">57.0</span></div>,
#  <div class="row-cell lxwratio"><span class="">1.01</span></div>,
#  <div class="row-cell pricepercarat"><span class="">£1,171</span></div>,
#  <div class="row-cell culet"><span class="">None</span></div>,
#  <div class="row-cell skus"><span class="">LD12116662</span></div>,
#  <div class="row-cell date"><span class="">Jun 13</span></div>,
#  <div class="cell-border-right compare" style="display:table-cell"><label class="comparison-diamonds-wrapper"><span class="comparison-star"></span></label></div>,
#  <div class="row-cell shape"><div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div></div>,
#  <div class="shape-cell-wrapper"><span><span class="diamond-search-sprite RD-360"></span></span><span class="single-cell">Round</span></div>,
#  <div class="row-cell price"><span class="">£292.80</span></div>,
#  <div class="row-cell carat"><span class="">0.25</span></div>,
#  <div class="row-cell cut"><div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div></div>,
#  <div class="cell-wrapper"><span class="label">Good</span><span class="label-small-view">Good</span></div>,
#  <div class="row-cell color"><span class="">F</span></div>,
#  <div class="row-cell clarity"><span class="">SI2</span></div>,
#  <div class="row-cell polish"><span class="">Very Good</span></div>,
#  <div class="row-cell symmetry"><span class="">Very Good</span></div>,
#  <div class="row-cell fluorescence"><span class="">None</span></div>,
#  ...]

# %%
cleanhtml(str(rows[3]))
