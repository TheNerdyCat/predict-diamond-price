# %% [markdown]
# # 1. Mining Diamond Data - Blue Nile®
#
# ## (a) Introduction
# In this series of notebooks we are mining diamond data from merchants on the web, and subsequently using Machine Learning to predict the price of a diamond. Diamond merchants often display data on the diamonds they are selling so people can peruse them and make a purchase online. They'll also usually have a comparison element with lots of features (the 5 C's etc.). Really though, if you're anything like me (a noob), how can you tell how the diamond is priced based on these features? And how can you tell if a specific diamond is a bargain or a rip-off?
#
# What we need is data, and a regression algorithm looking at price. This notebook is the first in the series, and in it we'll tackle scraping Blue Nile® data from [their website](https://www.bluenile.com/uk/diamond-search).
#
# ------------------------
#
# **This data is the sole property of Blue Nile®**, so please be respectful if you replicate. I cannot see any restriction to automated data collection in their Terms of Services (ToS) at the time of writing. I respect their robots.txt. I try and stick to web scraping best practises in these scripts (e.g. reasonable crawl rates), so if you are going to use it, please keep these in. This being said, Blue Nile still reserve the right to block access to any user, and we must stay up to date with their ToS. I am not a lawyer, so please seek professional advice if you are uncertain on the laws of the web scraping.
#
# ------------------------
#
# We'll start by importing our packages and defining a couple of functions.

# %% [markdown]
# ## (b) Import packages / define functions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.rcParams['figure.figsize'] = [12, 7] # Change default fig size

from bs4 import BeautifulSoup
import requests
import re
import string

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains

import itertools
import time # To help slow our functions down and time them
import random # To assign random floats to breaks, hiding predictable patterns

# %% [markdown]
# We'll define some useful functions that we'll be utilising a lot in the notebook. The last two functions are essential to working with HTML data.

# %%
def pause_random(start=0.6, stop=2):
    """
    Pause the function for a random amount of time between the two integers entered.
    """
    time.sleep(random.uniform(start, stop))

# %%
def get_page_content(page_link):
    """
    Scrape the targeted HTML and store as a bs object
    """
    page_response = requests.get(page_link, timeout=5)
    page_content = BeautifulSoup(page_response.content)
    return page_content

# %%
def cleanhtml(raw_html):
    """
    Remove HTML tags from string.
    """
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', raw_html)
    return cleantext

# %% [markdown]
# ## (c) Prepare Blue Nile® dataset
#
# In this section we create a function to prepare the Blue Nile table, and do some intial exploration to help our final crawler save time.
# For reference, I denote Blue Nile® as `bn` for short.

# %%
# For conciseness, Blue Nile we will denote as 'bn'
bn_link = 'https://www.bluenile.com/uk/diamond-search'

# %%
# Start web driver
browser = webdriver.Chrome('C:/Users/Edward Sims/Downloads/chromedriver.exe')
browser.get(bn_link)
pause_random(2,3)

# %%
# Continue past the cookie notice if it exists
try:
    cookie_continue = browser.find_element_by_xpath('/html/body/div[1]/button[3]')
    cookie_continue.click()
    pause_random()
except:
    pass

# %%
# If more filters is unselected, select it    
filter_status = browser.find_element_by_css_selector('.filters-overflow-button')
filter_status_str = str(filter_status.get_attribute('innerHTML'))
if 'More' in filter_status_str:
    filter_status.click()
    pause_random(1,2)

# %%
# Add extra options if they are not already added
polish_add = browser.find_element_by_xpath('//*[@id="polish-filter-container"]/div[1]/div/div/div')
symmetry_add = browser.find_element_by_xpath('//*[@id="symmetry-filter-container"]/div[1]/div/div/div')
fluorescence_add = browser.find_element_by_xpath('//*[@id="fluorescence-filter-container"]/div[1]/div/div/div')
depth_add = browser.find_element_by_xpath('//*[@id="depth-percentage-filter-container"]/div[1]/div/div/div')
table_add = browser.find_element_by_xpath('//*[@id="table-percentage-filter-container"]/div[1]/div/div/div')
lw_add = browser.find_element_by_xpath('//*[@id="length-to-width-ratio-filter-container"]/div[1]/div/div/div')

feature_add_all = [polish_add, symmetry_add, fluorescence_add, depth_add, table_add, lw_add]

for feature_add in feature_add_all:
    if 'pressed="True"' not in str(feature_add.get_attribute('outerHTML')):
        feature_add.click()
        pause_random()
        
culet_add = browser.find_element_by_xpath('//*[@id="culet-filter-container-accordion"]')
if 'Added' not in str(culet_add.get_attribute('outerHTML')):
    culet_add.click()
    pause_random()

# %%
# Add in all types of shape
round_details = browser.find_element_by_xpath('//*[@id="shape-filter-container-accordion"]/div/div[1]/div[3]')
princess_details = browser.find_element_by_xpath('//*[@id="shape-filter-container-accordion"]/div/div[2]/div[3]')
emerald_details = browser.find_element_by_xpath('//*[@id="shape-filter-container-accordion"]/div/div[3]/div[3]')
asscher_details = browser.find_element_by_xpath('//*[@id="shape-filter-container-accordion"]/div/div[4]/div[3]')
cushion_details = browser.find_element_by_xpath('//*[@id="shape-filter-container-accordion"]/div/div[5]/div[3]')
marquise_details = browser.find_element_by_xpath('//*[@id="shape-filter-container-accordion"]/div/div[6]/div[3]')
radiant_details = browser.find_element_by_xpath('//*[@id="shape-filter-container-accordion"]/div/div[7]/div[3]')
oval_details = browser.find_element_by_xpath('//*[@id="shape-filter-container-accordion"]/div/div[8]/div[3]')
pear_details = browser.find_element_by_xpath('//*[@id="shape-filter-container-accordion"]/div/div[9]/div[3]')
heart_details = browser.find_element_by_xpath('//*[@id="shape-filter-container-accordion"]/div/div[10]/div[3]')

shape_details_all = [round_details, princess_details, emerald_details, asscher_details, cushion_details, 
                     marquise_details, radiant_details, oval_details, pear_details, heart_details]

for shape_details in shape_details_all:
    if 'selected' not in str(shape_details.get_attribute('outerHTML')):
        shape_details.click()
        pause_random()

# %%
def get_num_results():
    """
    Scrapes the number of results shown in the price range.    
    """
    results_path = browser.find_element_by_xpath('//*[@id="react-app"]/div/div/div/div[4]/div[2]/button[1]')
    # Scrape HTML and clean
    results_val = cleanhtml(str(BeautifulSoup(results_path.get_attribute('innerHTML'))))
    # Strip  punctuation, and convert to integer
    results_val = re.sub(r'[^\w\s]','', results_val)
    results_val = int(results_val.split(' ')[2])
    return(results_val)

# %%
# Min and max price locations
min_price_box = browser.find_element_by_xpath('//*[@id="price-filter-container-accordion"]/div/fieldset/div/div[1]')
max_price_box = browser.find_element_by_xpath('//*[@id="price-filter-container-accordion"]/div/fieldset/div/div[2]')

min_price_box_input = browser.find_element_by_name('price-min-input')
max_price_box_input = browser.find_element_by_name('price-max-input')

# %%
# Assign default interval value
price_interval = 1000

min_price_box_html = min_price_box.get_attribute('innerHTML')
max_price_box_html = max_price_box.get_attribute('innerHTML')

# Get min and max values (without £ and comma values)
min_price_value = min_price_box_html.split('value=')[1].split('>')[0] # Get value string
min_price_value = int(min_price_value.translate(str.maketrans('', '', string.punctuation))) # Convert to int
min_price_value = min_price_value - 1 # Minus 1, so we can add 1 in the loop

max_price_value = max_price_box_html.split('value=')[1].split('>')[0] # Get value string
max_price_value = int(max_price_value.translate(str.maketrans('', '', string.punctuation))) # Convert to int

# %%
# Find a neutral zone to click on
neutral = browser.find_element_by_xpath('//*[@id="price-filter-container"]/div[1]')

# %%
def get_bn_data():
    """
    Loops through all the price values, scrapes the results and stores
    it into a dataframe.
    """
    def bn_scrape_table():
        bn_table = pd.DataFrame(columns = bn_headers)
        table_web_source = browser.find_element_by_id('diamond-result')
        table_html = BeautifulSoup(table_web_source.get_attribute('innerHTML'))
        # Scrape the table! First get the raw table html
        table_rows_html = table_html.find_all('a',{'class':'grid-row row'})
        # Then loop through each row 
        for row in table_rows_html:
            bn_data = []
            # And loop through each value
            for value in row.find_all('span'):
                bn_data.append(cleanhtml(str(value)))
            bn_data = list(filter(('').__ne__, bn_data)) # Remove all empty values
            del bn_data[4] # Delete index 4 in list as it returns two dupe vals - unique to their HTML
            
            bn_dict = dict(zip(bn_headers, bn_data))
            bn_table = bn_table.append(bn_dict, ignore_index=True)
        return bn_table
    
    start = time.time()
    bn_headers = []
    # Isolate the table headers HTML
    headers_data = browser.find_element_by_xpath('//*[@id="diamond-result"]/div[2]/div/div[1]/div')
    headers_html = BeautifulSoup(headers_data.get_attribute('innerHTML'))
    # Get the header values
    for div in headers_html.find_all('div'):
        for header in div.find_all('span'):
            bn_headers.append(cleanhtml(str(header)))
    bn_headers = list(filter(('').__ne__, bn_headers))
    del bn_headers[0] # Repeated value - likely an obstacle for web scrapers
    # Create a dataframe with our new headers
    bn_df = pd.DataFrame(columns = bn_headers)
    
    total_freq = get_num_results()
    cumul_freq = 0 # To cumulitively add the freqs as we go
    
    # Loop through prices
    for min_val in range(min_price_value, max_price_value, price_interval):
        #print(f'min_val: {min_val}')
        lower_price = min_val + 1 # Add 1 so there are no overlapping intervals
        higher_price = min_val + price_interval
        #print(f'lower_price: {lower_price}')
        #print(f'higher_price: {higher_price}')
        
        # Edit max price
        max_price_box = browser.find_element_by_xpath('//*[@id="price-filter-container-accordion"]/div/fieldset/div/div[2]')
        max_price_box_input = browser.find_element_by_name('price-max-input')
        browser.execute_script(f"arguments[0].value = '{higher_price}';", max_price_box_input)
        max_price_box.click()
        neutral.click()
        pause_random(1,2)
    
        # Edit min price
        min_price_box = browser.find_element_by_xpath('//*[@id="price-filter-container-accordion"]/div/fieldset/div/div[1]')
        min_price_box_input = browser.find_element_by_name('price-min-input')
        browser.execute_script(f"arguments[0].value = '{lower_price}';", min_price_box_input)
        min_price_box.click()
        neutral.click()
        pause_random(1,2)
    
        freq = get_num_results()
        cumul_freq = cumul_freq + freq
        
        # If there are less than 999 results left
        if (total_freq - cumul_freq) <= 999:
            # Skip to the max price value
            max_price_box = browser.find_element_by_xpath('//*[@id="price-filter-container-accordion"]/div/fieldset/div/div[2]')
            max_price_box_input = browser.find_element_by_name('price-max-input')
            browser.execute_script(f"arguments[0].value = '{max_price_value}';", max_price_box_input)
            max_price_box.click()
            neutral.click()
            
            browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            pause_random(7,8) # Wait for the table to load
            bn_df = bn_df.append(bn_scrape_table(), ignore_index=True)
            break # End the loop
        else:           
            # If there are over 999 results, divide the interval into smaller
            # intervals that approximately return 999 or less results for each.
            if freq > 999:
                sub_interval_number = freq / 999
                sub_interval_price = round(price_interval / sub_interval_number)
                sub_min_price_value = lower_price - 1
                sub_max_price_value = higher_price
                
                for min_val in range(sub_min_price_value, sub_max_price_value, sub_interval_price):
                    sub_lower_price = min_val + 1 # Add 1 so there are no overlapping intervals
                    sub_higher_price = min_val + sub_interval_price
                    
                    # Edit max price
                    max_price_box = browser.find_element_by_xpath('//*[@id="price-filter-container-accordion"]/div/fieldset/div/div[2]')
                    max_price_box_input = browser.find_element_by_name('price-max-input')
                    browser.execute_script(f"arguments[0].value = '{sub_higher_price}';", max_price_box_input)
                    max_price_box.click()
                    neutral.click()
                    pause_random(1,2)
                    
                    # Edit min price
                    min_price_box = browser.find_element_by_xpath('//*[@id="price-filter-container-accordion"]/div/fieldset/div/div[1]')
                    min_price_box_input = browser.find_element_by_name('price-min-input')
                    browser.execute_script(f"arguments[0].value = '{sub_lower_price}';", min_price_box_input)
                    min_price_box.click()
                    neutral.click()
                    pause_random(1,2)
                    
                    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                    pause_random(7,8) # Wait for the table to load
                    
                    bn_df = bn_df.append(bn_scrape_table(), ignore_index=True)
            # Scrape data as per normal
            else: 
                browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                pause_random(7,8) # Wait for the table to load
                bn_df = bn_df.append(bn_scrape_table(), ignore_index=True)
            
    end = time.time()
    print((end - start) / 60, 'mins to complete')
    return bn_df

# %%
bn_df = get_bn_data()
bn_df.to_csv('../input/bn_df.csv', index=False)
# Out:
# 62.58335721095403 mins to complete

# %%
bn_df
# Out:
#            Shape        Price Carat        Cut Color Clarity     Polish  \
# 0       Princess      £194.40  0.23  Very Good     F     SI2  Excellent
# 1       Princess      £211.20  0.24  Very Good     H     SI1  Excellent
# 2           Pear      £220.80  0.31  Very Good     E     SI2  Excellent
# 3        Emerald      £225.60  0.30  Very Good     K    VVS2  Very Good
# 4           Pear      £231.60  0.30  Very Good     I     SI2  Very Good
# ...          ...          ...   ...        ...   ...     ...        ...
# 159016     Round  £107,816.40  4.11      Ideal     E     VS2  Excellent
# 159017   Emerald  £107,817.60  5.02  Very Good     H     VS1  Excellent
# 159018   Asscher  £108,093.60  5.55  Very Good     I    VVS2  Excellent
# 159019     Round  £108,114.00  3.08      Ideal     E     VS1  Excellent
# 159020     Round  £108,204.00  5.04      Ideal     F     SI1  Excellent
#
#          Symmetry Fluorescence Depth Table   L/W Price/Ct Culet   Stock No.  \
# ...

# %% [markdown]
# ## (e) Data Cleaning and Visualisation
#
# Scraping took ~1 hour to complete. Now let's take a look at the data we have scraped, perform any necessary cleaning and build a picture of what the data can tell us.

# %%
bn_df = pd.read_csv('../input/bn_df.csv')
print(f'There are {bn_df.shape[0]} rows')
print(f'There are {bn_df.shape[1]} features')
# Out:
# There are 159021 rows
# There are 16 features

# %%
bn_df.head()
# Out:
#       Shape    Price  Carat        Cut Color Clarity     Polish   Symmetry  \
# 0  Princess  £194.40   0.23  Very Good     F     SI2  Excellent  Very Good
# 1  Princess  £211.20   0.24  Very Good     H     SI1  Excellent  Very Good
# 2      Pear  £220.80   0.31  Very Good     E     SI2  Excellent       Good
# 3   Emerald  £225.60   0.30  Very Good     K    VVS2  Very Good  Very Good
# 4      Pear  £231.60   0.30  Very Good     I     SI2  Very Good  Very Good
#
#   Fluorescence  Depth  Table   L/W Price/Ct Culet   Stock No. Dispatch Date
# 0         None   74.4   71.0  1.04     £845  None  LD13494026        Feb 20
# 1         None   74.7   74.0  1.03     £880  None  LD13494073        Feb 20
# 2       Medium   62.9   60.0  1.51     £712  None  LD13141213        Feb 20
# 3       Medium   67.3   64.0  1.33     £752  None  LD13461043        Feb 20
# 4         None   61.6   59.0  1.50     £772  None  LD13368015        Feb 20

# %%
bn_df.tail()
# Out:
#           Shape        Price  Carat        Cut Color Clarity     Polish  \
# 159016    Round  £107,816.40   4.11      Ideal     E     VS2  Excellent
# 159017  Emerald  £107,817.60   5.02  Very Good     H     VS1  Excellent
# 159018  Asscher  £108,093.60   5.55  Very Good     I    VVS2  Excellent
# 159019    Round  £108,114.00   3.08      Ideal     E     VS1  Excellent
# 159020    Round  £108,204.00   5.04      Ideal     F     SI1  Excellent
#
#          Symmetry Fluorescence  Depth  Table   L/W Price/Ct Culet   Stock No.  \
# 159016  Excellent         None   61.4   59.0  1.01  £26,233  None  LD13372487
# 159017  Excellent         None   68.8   61.0  1.44  £21,478  None  LD13415502
# 159018  Very Good        Faint   67.5   61.0  1.00  £19,476  None  LD01176511
# 159019  Excellent         None   61.1   58.0  1.01  £35,102  None  LD13465964
# 159020  Excellent         None   59.3   60.0  1.00  £21,469  None  LD13389580
#
#        Dispatch Date
# 159016        Feb 17
# ...

# %%
bn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159021 entries, 0 to 159020
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Shape          159021 non-null  object
#  1   Price          159021 non-null  object
#  2   Carat          159021 non-null  float64
#  3   Cut            159021 non-null  object
#  4   Color          159021 non-null  object
#  5   Clarity        159021 non-null  object
#  6   Polish         159021 non-null  object
#  7   Symmetry       159021 non-null  object
#  8   Fluorescence   159021 non-null  object
#  9   Depth          159021 non-null  float64
#  10  Table          159021 non-null  float64
#  11  L/W            159021 non-null  float64
#  12  Price/Ct       159021 non-null  object
#  13  Culet          159021 non-null  object
#  14  Stock No.      159021 non-null  object
#  15  Dispatch Date  159021 non-null  object
# dtypes: float64(4), object(12)
# ...

# %% [markdown]
# Numerical features need to be converted to floats - and the price features need a bit of cleaning before we can do that.

# %%
def remove_price_punctuation(x):
    x = x.replace('£', '')
    x = x.replace(',', '')
    return x
    
price_features = ['Price', 'Price/Ct']
bn_df['Price'] = bn_df['Price'].apply(remove_price_punctuation)
bn_df['Price/Ct'] = bn_df['Price/Ct'].apply(remove_price_punctuation)

features_num = ['Price', 'Carat', 'Depth' , 'Table', 'L/W', 'Price/Ct']
bn_df[features_num] = bn_df[features_num].astype('float')

# %% [markdown]
# We should convert 'None' values to actual nulls.

# %%
def convert_to_null(x):
    if x == 'None':
        x = None
    return x

for col in bn_df.columns:
    bn_df[col] = bn_df[col].apply(convert_to_null)

# %%
bn_df.isna().sum().plot(kind='bar')
plt.title('Number of Nulls by Feature')
plt.show()

# %% [markdown]
# It appears that both Fluorescence and Culet have a lot of nulls...

# %%
bn_df.loc[:, bn_df.dtypes == 'object'].nunique().plot(kind='bar')
plt.title('Number of Unique Objects by Object Type Feature')
plt.show()

# %% [markdown]
# Stock No. definitely is a unique ID that we can remove. We'll also get rid of Fluorescence and Culet due to their high numbers of nulls. And Dispatch Date doesn't look useful either.

# %%
rm_cols = ['Fluorescence', 'Culet', 'Stock No.', 'Dispatch Date']
bn_df.drop(rm_cols, axis=1, inplace = True)

# %% [markdown]
# Let's look at the numerical features now.

# %%
bn_df.describe()
# Out:
#                Price          Carat          Depth          Table  \
# count  159021.000000  159021.000000  159021.000000  159021.000000
# mean     5412.998208       0.884708      63.519491      59.676740
# std     10039.132757       0.683900       3.727233       4.491439
# min       194.400000       0.230000       4.000000       5.000000
# 25%       838.800000       0.420000      61.600000      57.000000
# 50%      1906.800000       0.700000      62.600000      58.000000
# 75%      5662.800000       1.030000      64.200000      61.000000
# max    108204.000000       9.010000      80.000000      85.000000
#
#                  L/W       Price/Ct
# count  159021.000000  159021.000000
# mean        1.083278    4054.239371
# std         0.181151    3210.243524
# min         0.780000     701.000000
# 25%         1.000000    1970.000000
# 50%         1.010000    2902.000000
# 75%         1.020000    5209.000000
# max         3.460000   40249.000000

# %% [markdown]
# The data are quite skewed to the lower end for each feature. There are some anomalies too that are really boosting the means.

# %%
bn_df['Price/Ct_calculated'] = bn_df['Price'] / bn_df['Carat']
bn_df['Price/Ct_diff'] = bn_df['Price/Ct'] - bn_df['Price/Ct_calculated']

# %%
sns.set_style('whitegrid')
sns.kdeplot(bn_df['Price/Ct_diff'], bw=0.05)
plt.title('Difference Between Provided Price/Ct and Calculated Price/Ct')
plt.show()

# %% [markdown]
# This is quite cool. The Price/Ct feature they give isn't exactly the same as what we calculate ourselves. Their distribution is perfectly symmetrical and very normal! Given that the differences are almost negligible though I expect it's a result of rounding. We won't keep the original feature due to this reason (we want the Price/Ct feature to be more exact if we can).

# %%
bn_df.drop(['Price/Ct', 'Price/Ct_diff'], axis=1, inplace=True)

# %%
bn_df
# Out:
#            Shape     Price  Carat        Cut Color Clarity     Polish  \
# 0       Princess     194.4   0.23  Very Good     F     SI2  Excellent
# 1       Princess     211.2   0.24  Very Good     H     SI1  Excellent
# 2           Pear     220.8   0.31  Very Good     E     SI2  Excellent
# 3        Emerald     225.6   0.30  Very Good     K    VVS2  Very Good
# 4           Pear     231.6   0.30  Very Good     I     SI2  Very Good
# ...          ...       ...    ...        ...   ...     ...        ...
# 159016     Round  107816.4   4.11      Ideal     E     VS2  Excellent
# 159017   Emerald  107817.6   5.02  Very Good     H     VS1  Excellent
# 159018   Asscher  108093.6   5.55  Very Good     I    VVS2  Excellent
# 159019     Round  108114.0   3.08      Ideal     E     VS1  Excellent
# 159020     Round  108204.0   5.04      Ideal     F     SI1  Excellent
#
#          Symmetry  Depth  Table   L/W  Price/Ct_calculated
# 0       Very Good   74.4   71.0  1.04           845.217391
# ...
